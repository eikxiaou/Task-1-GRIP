# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "http://bit.ly/w-data"
input_data = pd.read_csv(url)
input_data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
input_data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = [20,5])
plt.subplot(1,1,1)
plt.scatter(input_data['Hours'],input_data['Scores'])
plt.xlabel('cylinders')
plt.ylabel('mpg')
plt.title('abcd')
import seaborn as sns
sns.distplot(input_data['Scores'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.utils import shuffle
data = input_data
train_Set = data[:20]
train_sety = train_Set['Scores'];
train_setx = train_Set.drop(columns = ['Scores'])
train_setx
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4

# %%
import random
random.seed(1)
theta0 = random.uniform(-1,1);
theta1 = random.uniform(-1,1);

# %%
import numpy as np
X1 = train_setx['Hours'];

M1= np.mean(X1);
S1 = np.std(X1);
X1 = (X1 - M1)/S1;
Y = train_sety
L = len(X1)

# %%
iteration_Nos = range(1, 50)
err_F = [None] * len(iteration_Nos)

for i in iteration_Nos:
  h = ((1/L)*np.sum(np.square(theta0 + theta1*X1  - Y)))
  err_F[i-1] = h;
  theta0 = theta0 - (alpha/L)*np.sum((2*(theta0 + theta1*X1  - Y)));
  theta1 = theta1 - (alpha/L)*np.sum(np.multiply(2*(theta0 + theta1*X1  - Y),X1));
  plt.clf()
  plt.subplot(1,2,1);
  plt.plot(range(1, i), err_F[1:i])
  plt.xlabel('Iteration No.')
  plt.ylabel('Cost')
  plt.subplot(1,2,2);
  plt.scatter(X1, Y)
  X_R = np.arange(np.min(train_setx['Hours']),np.max(train_setx['Hours']), 0.1);
  # create a x axis with  min to max
  X_R = (X_R-M1)/S1;
  plt.plot(X_R, theta0 + theta1*X_R, 'r');
  plt.show()
  #ploting the red line
  print('Error = ',h, 'theta0 = ', theta0, 'theta1 = ', theta1,'\n')
# Out:
# Error =  3209.6361713102992 theta0 =  19.681237092934882 theta1 =  10.302932679701492
# Error =  1173.6944731631515 theta0 =  31.92874225576093 theta1 =  16.067771803197708
# Error =  440.75546183017815 theta0 =  39.27724535345656 theta1 =  19.526675277295436
# Error =  176.89741775030802 theta0 =  43.68634721207393 theta1 =  21.602017361754076
# Error =  81.90852188155472 theta0 =  46.33180832724436 theta1 =  22.84722261242926
# Error =  47.712519368803484 theta0 =  47.91908499634662 theta1 =  23.59434576283437
# Error =  35.401958464213024 theta0 =  48.87145099780797 theta1 =  24.042619653077434
# Error =  30.97015653856051 theta0 =  49.44287059868478 theta1 =  24.311583987223273
# Error =  29.374707845325595 theta0 =  49.785722359210865 theta1 =  24.472962587710775
# Error =  28.800346315761022 theta0 =  49.991433415526515 theta1 =  24.569789748003277
# Error =  28.59357616511777 theta0 =  50.11486004931591 theta1 =  24.62788604417878
# ...

# %%
theta0+theta1*((9.25-M1)/S1)
# Out:
# 91.0948544156111

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(train_setx,train_sety)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
line = regressor.coef_*train_setx+regressor.intercept_

# Plotting for the test data
plt.scatter(train_setx,train_sety)
plt.plot(train_setx, line);
plt.show()
# Out:
# array([9.52038609])

# %%
testset=(train_setx[:6]) # Testing data - In Hours
y_pred = regressor.predict(testset) 
print(y_pred)
df = pd.DataFrame({'Actual': train_sety[:6], 'Predicted': y_pred})  
df 
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(testset, y_pred))
# Out:
# [26.83224828 51.58525212 33.49651854 83.95456485 36.35263437 17.31186218]
# Mean Absolute Error: 37.53884672312674
